# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
df_sic_peers = pd.read_csv("df_sic_peers.csv")
df_sic_peers[["ticker", "datekey"]][df_sic_peers["ticker"] == "ACI"]
# Per manual inspection, ACI's price series starts around the end of
# 6/2020, but there are financial statement obs going back to 2018.
# I think this is because of the data filed with the S1 statement
# for the IPO.

len(df_sic_peers["ticker"].unique())
df_sic_peers["ticker"].unique()
df_prices = pd.read_csv("prices.csv")
len(df_prices["ticker"].unique())
# There are 19 unique tickers in the financial statement data,
# but 20 in the price data.

df_prices["ticker"].unique()
# Below identifies the ticker in the price data that is not in the
# financial statement data.

for i in df_prices["ticker"].unique():
    if i not in df_sic_peers["ticker"].unique():
        print(i)
# Per manual inspection of the SF1 table, CBD only has ART, ARY, MRT and MRY
# for dimension so they weren't included in the original data pull.
# The original data query had dimension="ARQ"

df_prices[df_prices["ticker"] == "ACI"]
df_prices[
    (df_prices["ticker"] == "ACI")
    & (df_prices["date"] >= "2018-05-07")
    & (df_prices["date"] <= "2020-06-24")
]
# Above shows no price data before the end of June, 2020.

df_sic_peers.head()
# Below identifies SEC filing dates without a stock price date. At first,
# I thought these would all be cases of companies filing on holidays or
# weekends, but after manual inspection it appears that most of these
# are related to IPO's. See notes and further inspection below the loop.
# First, itererate through the dataframe based on the unique tickers.

for i in df_sic_peers["ticker"].unique():
    df_temp_sic = df_sic_peers[df_sic_peers["ticker"] == i]
    df_temp_prices = df_prices[df_prices["ticker"] == i]
    # Create two lists, one that contains the dates from the SEC fillings
    # and the other that contains dates from the stock prices series.
    lister = []
    lister_2 = []
    for j in df_temp_sic["datekey"]:
        lister.append(j)
    for q in df_temp_prices["date"]:
        lister_2.append(q)
    # Identify financial statement dates without stock price data. Also,
    # see if shifting the SEC reporting dates forward by a day or two and
    # backward by a day or two result in mergeable dates. Note that this
    # only worked for GO and FWMHQ around their IPOs. This is further
    # examined below the loop. GO's first trading day was 6/20/19
    # and FWMHQ's first trading day was 4/15/13. The loops further
    # condition on pd.dattime().weekday() values which are 0 for Monday
    # and 6 for Sunday. .weekday() values in the data are [0-4].
    for z in lister:
        if z not in lister_2:
            print("Non-trading date fillings:", i, z)
            print("Day of the week is:", i, z, pd.to_datetime(z).weekday())
            print(
                str(pd.to_datetime(z).date()),
                str(pd.to_datetime(z).date() + pd.Timedelta("1 day")),
            )
            if pd.to_datetime(z).weekday() <= 3:
                print(
                    "Plus one day:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() + pd.Timedelta("1 day")),
                    str(pd.to_datetime(z).date() + pd.Timedelta("1 day"))
                    in lister_2,
                )
            if pd.to_datetime(z).weekday() <= 3:
                print(
                    "Minus one day:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() - pd.Timedelta("1 day")),
                    str(pd.to_datetime(z).date() - pd.Timedelta("1 day"))
                    in lister_2,
                )
            if pd.to_datetime(z).weekday() <= 3:
                print(
                    "Plus two days:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() + pd.Timedelta("2 days")),
                    str(pd.to_datetime(z).date() + pd.Timedelta("2 days"))
                    in lister_2,
                )
            if pd.to_datetime(z).weekday() <= 3:
                print(
                    "Minus two days:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() - pd.Timedelta("2 days")),
                    str(pd.to_datetime(z).date() - pd.Timedelta("2 days"))
                    in lister_2,
                )
            if (pd.to_datetime(z).weekday() > 3) & (
                pd.to_datetime(z).weekday() <= 5
            ):
                print(
                    "Plus one day:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() + pd.Timedelta("1 day")),
                    str(pd.to_datetime(z).date() + pd.Timedelta("1 day"))
                    in lister_2,
                )
                print(
                    "Minus one day:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() - pd.Timedelta("1 day")),
                    str(pd.to_datetime(z).date() - pd.Timedelta("1 day"))
                    in lister_2,
                )
                print(
                    "Plus two days:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() + pd.Timedelta("2 days")),
                    str(pd.to_datetime(z).date() + pd.Timedelta("2 days"))
                    in lister_2,
                )
                print(
                    "Minus two days:",
                    i,
                    z,
                    str(pd.to_datetime(z).date() - pd.Timedelta("2 days")),
                    str(pd.to_datetime(z).date() - pd.Timedelta("2 days"))
                    in lister_2,
                )
# Out:
# CBD
# Non-trading date fillings: SWY 2015-03-04
# Day of the week is: SWY 2015-03-04 2
# 2015-03-04 2015-03-05
# Plus one day: SWY 2015-03-04 2015-03-05 False
# Minus one day: SWY 2015-03-04 2015-03-03 False
# Plus two days: SWY 2015-03-04 2015-03-06 False
# Minus two days: SWY 2015-03-04 2015-03-02 False
# Non-trading date fillings: SFM 2013-07-29
# Day of the week is: SFM 2013-07-29 0
# 2013-07-29 2013-07-30
# Plus one day: SFM 2013-07-29 2013-07-30 False
# Minus one day: SFM 2013-07-29 2013-07-28 False
# Plus two days: SFM 2013-07-29 2013-07-31 False
# Minus two days: SFM 2013-07-29 2013-07-27 False
# Non-trading date fillings: SFM 2013-07-22
# Day of the week is: SFM 2013-07-22 0
# 2013-07-22 2013-07-23
# Plus one day: SFM 2013-07-22 2013-07-23 False
# Minus one day: SFM 2013-07-22 2013-07-21 False
# Plus two days: SFM 2013-07-22 2013-07-24 False
# Minus two days: SFM 2013-07-22 2013-07-20 False
# Non-trading date fillings: NGVC 2012-07-20
# Day of the week is: NGVC 2012-07-20 4
# 2012-07-20 2012-07-21
# Plus one day: NGVC 2012-07-20 2012-07-21 False
# Minus one day: NGVC 2012-07-20 2012-07-19 False
# Plus two days: NGVC 2012-07-20 2012-07-22 False
# Minus two days: NGVC 2012-07-20 2012-07-18 False
# Non-trading date fillings: KR 2012-06-26
# Day of the week is: KR 2012-06-26 1
# 2012-06-26 2012-06-27
# Plus one day: KR 2012-06-26 2012-06-27 False
# Minus one day: KR 2012-06-26 2012-06-25 False
# Plus two days: KR 2012-06-26 2012-06-28 False
# Minus two days: KR 2012-06-26 2012-06-24 False
# Non-trading date fillings: IFMK 2016-12-16
# Day of the week is: IFMK 2016-12-16 4
# 2016-12-16 2016-12-17
# Plus one day: IFMK 2016-12-16 2016-12-17 False
# Minus one day: IFMK 2016-12-16 2016-12-15 False
# Plus two days: IFMK 2016-12-16 2016-12-18 False
# Minus two days: IFMK 2016-12-16 2016-12-14 False
# Non-trading date fillings: IFMK 2016-12-09
# Day of the week is: IFMK 2016-12-09 4
# 2016-12-09 2016-12-10
# Plus one day: IFMK 2016-12-09 2016-12-10 False
# Minus one day: IFMK 2016-12-09 2016-12-08 False
# Plus two days: IFMK 2016-12-09 2016-12-11 False
# Minus two days: ACI 2020-01-08 2020-01-06 False
# Non-trading date fillings: ACI 2019-10-16
# Day of the week is: ACI 2019-10-16 2
# 2019-10-16 2019-10-17
# Plus one day: ACI 2019-10-16 2019-10-17 False
# Minus one day: ACI 2019-10-16 2019-10-15 False
# Plus two days: ACI 2019-10-16 2019-10-18 False
# Minus two days: ACI 2019-10-16 2019-10-14 False
# Non-trading date fillings: ACI 2019-07-24
# Day of the week is: ACI 2019-07-24 2
# 2019-07-24 2019-07-25
# Plus one day: ACI 2019-07-24 2019-07-25 False
# Minus one day: ACI 2019-07-24 2019-07-23 False
# Plus two days: ACI 2019-07-24 2019-07-26 False
# Minus two days: ACI 2019-07-24 2019-07-22 False
# Non-trading date fillings: ACI 2019-04-24
# Day of the week is: ACI 2019-04-24 2
# 2019-04-24 2019-04-25
# Plus one day: ACI 2019-04-24 2019-04-25 False
# Minus one day: ACI 2019-04-24 2019-04-23 False
# Plus two days: ACI 2019-04-24 2019-04-26 False
# Minus two days: ACI 2019-04-24 2019-04-22 False
# Non-trading date fillings: ACI 2019-01-15
# Day of the week is: ACI 2019-01-15 1
# 2019-01-15 2019-01-16
# Plus one day: ACI 2019-01-15 2019-01-16 False
# Minus one day: ACI 2019-01-15 2019-01-14 False
# Plus two days: ACI 2019-01-15 2019-01-17 False
# Minus two days: ACI 2019-01-15 2019-01-13 False
# Non-trading date fillings: ACI 2018-10-18
# Day of the week is: ACI 2018-10-18 3
# 2018-10-18 2018-10-19
# Plus one day: ACI 2018-10-18 2018-10-19 False
# Minus one day: ACI 2018-10-18 2018-10-17 False
# Plus two days: ACI 2018-10-18 2018-10-20 False
# Minus two days: ACI 2018-10-18 2018-10-16 False
# Non-trading date fillings: ACI 2018-07-25
# Day of the week is: ACI 2018-07-25 2
# 2018-07-25 2018-07-26
# Plus one day: ACI 2018-07-25 2018-07-26 False
# Minus one day: ACI 2018-07-25 2018-07-24 False
# Plus two days: ACI 2018-07-25 2018-07-27 False
# Minus two days: ACI 2018-07-25 2018-07-23 False
# Non-trading date fillings: ACI 2018-05-11
# Day of the week is: ACI 2018-05-11 4
# 2018-05-11 2018-05-12
# Plus one day: ACI 2018-05-11 2018-05-12 False
# Minus one day: ACI 2018-05-11 2018-05-10 False
# Plus two days: ACI 2018-05-11 2018-05-13 False
# Minus two days: ACI 2018-05-11 2018-05-09 False

# %%
df_prices[
    (df_prices["ticker"] == "SWY")
    & (df_prices["date"] >= "2015-03-01")
    & (df_prices["date"] <= "2015-03-10")
]

df_prices[df_prices["ticker"] == "SWY"]
df_prices[
    (df_prices["ticker"] == "GO")
    & (df_prices["date"] >= "2019-06-01")
    & (df_prices["date"] <= "2019-06-30")
]

df_prices[
    (df_prices["ticker"] == "FWMHQ")
    & (df_prices["date"] >= "2013-04-01")
    & (df_prices["date"] <= "2013-04-30")
]

df_sic_peers.head()
# Out:
#   ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0    WMK       ARQ   2021-03-31  2021-05-06   2021-03-27  2021-05-06
# 1    WMK       ARQ   2020-12-31  2021-03-11   2020-12-26  2021-05-06
#      ps1  receivables       retearn       revenue    revenueusd  rnd  roa  \
# 0  0.353   44598000.0  1.299653e+09  1.006340e+09  1.006340e+09  0.0  NaN
# 1  0.386   56760000.0  1.283737e+09  1.025691e+09  1.025691e+09  0.0  NaN
# 2  0.315   50726000.0  1.272655e+09  1.002387e+09  1.002387e+09  0.0  NaN
# 3  0.344   48541000.0  1.249657e+09  1.098704e+09  1.098704e+09  0.0  NaN
# 4  0.396   56952000.0  1.216524e+09  9.858200e+08  9.858200e+08  0.0  NaN
#
#    roe  roic  ros  sbcomp         sgna  sharefactor   sharesbas    shareswa  \
# 0  NaN   NaN  NaN     0.0  235556000.0          1.0  26898443.0  26898443.0
# 1  NaN   NaN  NaN     0.0  242126000.0          1.0  26898443.0  26898443.0
# 2  NaN   NaN  NaN     0.0  231527000.0          1.0  26898443.0  26898443.0
# 3  NaN   NaN  NaN     0.0  236886000.0          1.0  26898443.0  26898443.0
# 4  NaN   NaN  NaN     0.0  226719000.0          1.0  26898443.0  26898443.0
#
#    shareswadil     sps     tangibles  taxassets      taxexp  taxliabilities  \
# 0   26898443.0  37.413  1.715185e+09        0.0   8415000.0     115435000.0
# 1   26898443.0  38.132  1.750532e+09        0.0   8246000.0     108462000.0
# 2   26898443.0  37.266  1.686571e+09        0.0  12142000.0     109646000.0
# 3   26898443.0  40.846  1.668504e+09        0.0  14978000.0     129294000.0
# 4   26898443.0  36.650  1.646325e+09        0.0   9396000.0     114581000.0
#
#     tbvps  workingcapital
# 0  63.765     288957000.0
# 1  65.079     279933000.0
# 2  62.701     286083000.0
# 3  62.030     267061000.0
# 4  61.205     229925000.0

# %%
df_sic_peers.loc[
    (df_sic_peers["datekey"] == "2019-06-18")
    & (df_sic_peers["ticker"] == "GO")
]

df_sic_peers.loc[
    (df_sic_peers["datekey"] == "2019-06-18")
    & (df_sic_peers["ticker"] == "GO"),
    "datekey",
] = "2019-06-20"

df_sic_peers.loc[
    (df_sic_peers["datekey"] == "2019-06-20")
    & (df_sic_peers["ticker"] == "GO")
]

df_sic_peers.loc[
    (df_sic_peers["datekey"] == "2013-04-16")
    & (df_sic_peers["ticker"] == "FWMHQ")
]

df_sic_peers.loc[
    (df_sic_peers["datekey"] == "2013-04-16")
    & (df_sic_peers["ticker"] == "FWMHQ"),
    "datekey",
] = "2013-04-17"

df_sic_peers.loc[
    (df_sic_peers["datekey"] == "2013-04-17")
    & (df_sic_peers["ticker"] == "FWMHQ")
]
# Out:
#     ticker dimension calendardate     datekey reportperiod lastupdated  \
# 361  FWMHQ       ARQ   2012-12-31  2013-04-17   2012-12-30  2019-06-07
#
#      accoci       assets  assetsavg     assetsc     assetsnc  assetturnover  \
# 361     0.0  339178000.0        NaN  75015000.0  264163000.0            NaN
#
#       bvps  capex     cashneq  cashnequsd  cor  consolinc  currentratio  \
# 361 -5.324    NaN  29172000.0  29172000.0  NaN        NaN         1.273
#
#         de         debt      debtc       debtnc      debtusd  deferredrev  \
# 361 -1.513  254627000.0  2600000.0  252027000.0  254627000.0          0.0
#
#      depamor  deposits  divyield  dps  ebit  ebitda  ebitdamargin  ebitdausd  \
# 361      NaN       0.0       NaN  0.0   NaN     NaN           NaN        NaN
#
#      ebitusd  ebt  eps  epsdil  epsusd       equity  equityavg    equityusd  \
# 361      NaN  NaN  NaN     NaN     NaN -219570000.0        NaN -219570000.0
#
#      ev  evebit  evebitda  fcf  fcfps  fxusd  gp  grossmargin  intangibles  \
# 361 NaN     NaN       NaN  NaN    NaN    1.0 NaN          NaN  121146000.0
#
#      intexp       invcap  invcapavg   inventory  investments  investmentsc  \
# 361     NaN  384581000.0        NaN  24062000.0          0.0           0.0
#
#      investmentsnc  liabilities  liabilitiesc  liabilitiesnc  marketcap  ncf  \
# 361            0.0  332215000.0    58906000.0    273309000.0        NaN  NaN
#
#      ncfbus  ncfcommon  ncfdebt  ncfdiv  ncff  ncfi  ncfinv  ncfo  ncfx  \
# 361     NaN        NaN      NaN     NaN   NaN   NaN     NaN   NaN   NaN
#
#      netinc  netinccmn  netinccmnusd  netincdis  netincnci  netmargin  opex  \
# 361     NaN        NaN           NaN        NaN        NaN        NaN   NaN
#
#      opinc    payables  payoutratio  pb  pe  pe1      ppnenet  prefdivis  \
# 361    NaN  38174000.0          NaN NaN NaN  NaN  120352000.0        NaN
#
#      price  ps  ps1  receivables      retearn  revenue  revenueusd  rnd  roa  \
# 361    NaN NaN  NaN    8928000.0 -219570000.0      NaN         NaN  NaN  NaN
#
#      roe  roic  ros  sbcomp  sgna  sharefactor   sharesbas    shareswa  \
# 361  NaN   NaN  NaN     NaN   NaN          1.0  41238260.0  41238260.0
#
#      shareswadil  sps    tangibles  taxassets  taxexp  taxliabilities  tbvps  \
# 361          NaN  NaN  218032000.0  4856000.0     NaN             0.0  5.287
#
#      workingcapital
# 361      16109000.0

# %%
df_sic_peers.info(verbose=True)
df_prices.info()
# Convert date variables to datetime.

df_sic_peers["datekey"] = pd.to_datetime(df_sic_peers["datekey"])
df_prices["date"] = pd.to_datetime(df_prices["date"])
df_sic_peers.rename(columns={"datekey": "date"}, inplace=True)
# Merge

df = pd.merge(df_prices, df_sic_peers, on=["ticker", "date"], how="left")
df.head()
len(df)
len(df_prices)
len(df_sic_peers)
# Sort by ticker and datekey

df.sort_values(by=["ticker", "date"], ascending=[True, True], inplace=True)
df.head()
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 111 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   ticker          object
#  1   dimension       object
#  2   calendardate    object
#  3   datekey         object
#  4   reportperiod    object
#  5   lastupdated     object
#  6   accoci          float64
#  7   assets          float64
#  8   assetsavg       float64
#  9   assetsc         float64
#  10  assetsnc        float64
#  11  assetturnover   float64
#  12  bvps            float64
#  13  capex           float64
#  14  cashneq         float64
#  15  cashnequsd      float64
#  16  cor             float64
#  17  consolinc       float64
#  18  currentratio    float64
#  19  de              float64
#  20  debt            float64
#  21  debtc           float64
#  22  debtnc          float64
#  23  debtusd         float64
#  24  deferredrev     float64
#  25  depamor         float64
#  26  deposits        float64
#  27  divyield        float64
#  28  dps             float64
#  29  ebit            float64
#  30  ebitda          float64
#  31  ebitdamargin    float64
#  32  ebitdausd       float64
#  33  ebitusd         float64
#  34  ebt             float64
#  35  eps             float64
#  36  epsdil          float64
#  37  epsusd          float64
#  38  equity          float64
#  39  equityavg       float64
#  40  equityusd       float64
#  41  ev              float64
#  42  evebit          float64
#  43  evebitda        float64
#  44  fcf             float64
#  45  fcfps           float64
#  46  fxusd           float64
#  47  gp              float64
#  48  grossmargin     float64
#  49  intangibles     float64
#  50  intexp          float64
#  51  invcap          float64
#  52  invcapavg       float64
#  53  inventory       float64
#  54  investments     float64
#  55  investmentsc    float64
#  56  investmentsnc   float64
#  57  liabilities     float64
#  58  liabilitiesc    float64
#  59  liabilitiesnc   float64
#  60  marketcap       float64
#  61  ncf             float64
#  62  ncfbus          float64
#  63  ncfcommon       float64
#  64  ncfdebt         float64
#  65  ncfdiv          float64
#  66  ncff            float64
#  67  ncfi            float64
#  68  ncfinv          float64
#  69  ncfo            float64
#  70  ncfx            float64
#  71  netinc          float64
#  72  netinccmn       float64
#  73  netinccmnusd    float64
#  74  netincdis       float64
#  75  netincnci       float64
#  76  netmargin       float64
#  77  opex            float64
#  78  opinc           float64
#  79  payables        float64
#  80  payoutratio     float64
#  81  pb              float64
#  82  pe              float64
#  83  pe1             float64
#  84  ppnenet         float64
#  85  prefdivis       float64
#  86  price           float64
#  87  ps              float64
#  88  ps1             float64
#  89  receivables     float64
#  90  retearn         float64
#  91  revenue         float64
#  92  revenueusd      float64
#  93  rnd             float64
#  94  roa             float64
#  95  roe             float64
#  96  roic            float64
#  97  ros             float64
#  98  sbcomp          float64
#  99  sgna            float64
#  100 sharefactor     float64
#  101 sharesbas       float64
#  102 shareswa        float64
#  103 shareswadil     float64
#  104 sps             float64
#  105 tangibles       float64
#  106 taxassets       float64
#  107 taxexp          float64
#  108 taxliabilities  float64
#  109 tbvps           float64
#  110 workingcapital  float64
# dtypes: float64(105), object(6)
# memory usage: 333.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25918 entries, 0 to 25917
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ticker       25918 non-null  object
#  1   date         25918 non-null  object
#  2   open         25918 non-null  float64
#  3   high         25918 non-null  float64
#  4   low          25918 non-null  float64
#  5   close        25918 non-null  float64
#  6   volume       25918 non-null  float64
#  7   closeadj     25918 non-null  float64
#  8   closeunadj   25918 non-null  float64
#  9   lastupdated  25918 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 2.0+ MB
#   ticker       date   open   high    low  close      volume  closeadj  \
# 0    ACI 2020-06-26  15.50  16.50  15.31  15.45  37216510.0    15.185
# 1    ACI 2020-06-29  15.89  16.01  15.50  15.57   7349059.0    15.303
# 2    ACI 2020-06-30  15.57  15.90  15.45  15.77   5030640.0    15.500
# 3    ACI 2020-07-01  15.79  15.89  15.55  15.76   3400498.0    15.490
# 4    ACI 2020-07-02  15.82  15.89  15.60  15.81   7190929.0    15.539
#
#    closeunadj lastupdated_x dimension calendardate reportperiod lastupdated_y  \
# 0       15.45    2021-04-26       NaN          NaN          NaN           NaN
# 1       15.57    2021-04-26       NaN          NaN          NaN           NaN
# 2       15.77    2021-04-26       NaN          NaN          NaN           NaN
# 3       15.76    2021-04-26       NaN          NaN          NaN           NaN
# 0            NaN        NaN  NaN     NaN        NaN      NaN     NaN   NaN
# 1            NaN        NaN  NaN     NaN        NaN      NaN     NaN   NaN
# 2            NaN        NaN  NaN     NaN        NaN      NaN     NaN   NaN
# 3            NaN        NaN  NaN     NaN        NaN      NaN     NaN   NaN
# 4            NaN        NaN  NaN     NaN        NaN      NaN     NaN   NaN
#
#    ncfi  ncfinv  ncfo  ncfx  netinc  netinccmn  netinccmnusd  netincdis  \
# 0   NaN     NaN   NaN   NaN     NaN        NaN           NaN        NaN
# 1   NaN     NaN   NaN   NaN     NaN        NaN           NaN        NaN
# 2   NaN     NaN   NaN   NaN     NaN        NaN           NaN        NaN
# 3   NaN     NaN   NaN   NaN     NaN        NaN           NaN        NaN
# 4   NaN     NaN   NaN   NaN     NaN        NaN           NaN        NaN
#
#    netincnci  netmargin  opex  opinc  payables  payoutratio  pb  pe  pe1  \
# 0        NaN        NaN   NaN    NaN       NaN          NaN NaN NaN  NaN
# 1        NaN        NaN   NaN    NaN       NaN          NaN NaN NaN  NaN
# 2        NaN        NaN   NaN    NaN       NaN          NaN NaN NaN  NaN
# 3        NaN        NaN   NaN    NaN       NaN          NaN NaN NaN  NaN
# 4        NaN        NaN   NaN    NaN       NaN          NaN NaN NaN  NaN
#
#    ppnenet  prefdivis  price  ps  ps1  receivables  retearn  revenue  \
# 0      NaN        NaN    NaN NaN  NaN          NaN      NaN      NaN
# 1      NaN        NaN    NaN NaN  NaN          NaN      NaN      NaN
# 2      NaN        NaN    NaN NaN  NaN          NaN      NaN      NaN
# 3      NaN        NaN    NaN NaN  NaN          NaN      NaN      NaN
# 4      NaN        NaN    NaN NaN  NaN          NaN      NaN      NaN
#
#    revenueusd  rnd  roa  roe  roic  ros  sbcomp  sgna  sharefactor  sharesbas  \
# 0         NaN  NaN  NaN  NaN   NaN  NaN     NaN   NaN          NaN        NaN
# 1         NaN  NaN  NaN  NaN   NaN  NaN     NaN   NaN          NaN        NaN
# 2         NaN  NaN  NaN  NaN   NaN  NaN     NaN   NaN          NaN        NaN
# 3         NaN  NaN  NaN  NaN   NaN  NaN     NaN   NaN          NaN        NaN
# 4         NaN  NaN  NaN  NaN   NaN  NaN     NaN   NaN          NaN        NaN
#
#    shareswa  shareswadil  sps  tangibles  taxassets  taxexp  taxliabilities  \
# 0       NaN          NaN  NaN        NaN        NaN     NaN             NaN
# 1       NaN          NaN  NaN        NaN        NaN     NaN             NaN
# 2       NaN          NaN  NaN        NaN        NaN     NaN             NaN
# 3       NaN          NaN  NaN        NaN        NaN     NaN             NaN
# 4       NaN          NaN  NaN        NaN        NaN     NaN             NaN
#
#    tbvps  workingcapital
# 0    NaN             NaN
# 1    NaN             NaN
# 2    NaN             NaN
# 3    NaN             NaN
# 4    NaN             NaN

# %%
lister = []
def cumRet(df, window):
    """ This function calculates the return for the period of t-1 from the
    EDGAR file date through t + window. New dataframes for each ticker
    are then stored into a list, lister. These will be merged in later
    with the dataframe, df, that has both price and financial
    statement data.  """
    for i, t in enumerate(df["ticker"].unique()):
        df_temp = df[df["ticker"] == t].copy()
        # df_temp['cum_ret']= np.nan
        df_temp.loc[:, "cum_ret"] = np.nan
        cut_offs = []
        for j in df_temp["calendardate"][
            df_temp["calendardate"].notnull()
        ].index:
            cut_offs.append(j)
        for x in cut_offs:
            # start the window from the day before earnings are announced.
            # this is to try and deal with companies that may release earnings
            # either after markets close on a given day, before
            # markets open on a given day, or during a trading day.
            # Below modifies starting index for GO and FWMHQ who
            # have no price observations before the IPO filings.
            if x - 1 not in df_temp.index:
                start_index = df_temp.index.min()
            else:
                start_index = x - 1
            # if there are not t-1 plus 16 trading days after a
            # given announcement, use the last trading day for the
            # company in the dataframe.
            if x + window not in df_temp.index:
                end_index = df_temp.index.max()
            else:
                end_index = start_index + window
            print(
                "ticker is",
                t,
                "start_index",
                start_index,
                "end_index",
                end_index,
            )
            print(
                "start_price",
                df_temp["close"].loc[start_index],
                "end_price",
                df_temp["close"].loc[end_index],
            )
            # modify the start_index by adding one to line up with
            # the actual earnings report release date.
            df_temp["cum_ret"].loc[start_index + 1] = (
                df_temp["close"].loc[end_index]
                - df_temp["close"].loc[start_index]
            ) / df_temp["close"].loc[start_index]
        print("appending", df_temp["ticker"].iloc[0])
        lister.append(df_temp[["ticker", "date", "cum_ret"]])

# %%
cumRet(df, 16)
# Out:
# ticker is ACI start_index 25 end_index 41
# start_price 14.83 end_price 14.59
# ticker is ACI start_index 80 end_index 96
# start_price 15.22 end_price 14.98
# ticker is ACI start_index 137 end_index 153
# start_price 17.1 end_price 16.71
# ticker is ACI start_index 209 end_index 217
# start_price 18.11 end_price 19.18
# appending ACI
# ticker is ARDNA start_index 240 end_index 256
# start_price 82.6 end_price 89.0
# ticker is ARDNA start_index 304 end_index 320
# start_price 95.88 end_price 111.99
# ticker is ARDNA start_index 388 end_index 404
# start_price 98.31 end_price 100.15
# ticker is ARDNA start_index 429 end_index 445
# start_price 98.65 end_price 107.54
# ticker is ARDNA start_index 493 end_index 509
# start_price 132.78 end_price 134.6
# ticker is ARDNA start_index 557 end_index 573
# start_price 129.85 end_price 129.99
# appending ARDNA
# ticker is ASAI start_index 664 end_index 671
# start_price 14.81 end_price 16.86
# appending ASAI
# appending CBD
# ticker is FWMHQ start_index 2899 end_index 2915
# start_price 17.35 end_price 18.2
# ticker is FWMHQ start_index 2933 end_index 2949
# start_price 20.73 end_price 23.97
# ticker is FWMHQ start_index 2977 end_index 2993
# start_price 25.83 end_price 22.53
# ticker is FWMHQ start_index 3041 end_index 3057
# start_price 25.46 end_price 18.99
# ticker is FWMHQ start_index 3102 end_index 3118
# start_price 11.14 end_price 7.8
# ticker is FWMHQ start_index 3179 end_index 3195
# start_price 6.75 end_price 6.79
# ticker is FWMHQ start_index 3228 end_index 3244
# start_price 5.74 end_price 4.51
# ticker is FWMHQ start_index 3292 end_index 3308
# start_price 2.59 end_price 3.71
# ticker is FWMHQ start_index 3353 end_index 3369
# start_price 5.02 end_price 5.57
# ticker is FWMHQ start_index 3428 end_index 3444
# start_price 4.63 end_price 4.04
# ticker is FWMHQ start_index 3477 end_index 3493
# start_price 3.02 end_price 2.37
# ticker is FWMHQ start_index 3538 end_index 3554
# start_price 1.71 end_price 1.08
# ticker is FWMHQ start_index 3605 end_index 3621
# start_price 0.499 end_price 0.301
# appending FWMHQ
# ticker is GO start_index 3711 end_index 3727
# start_price 28.51 end_price 35.38
# ticker is GO start_index 3747 end_index 3763
# start_price 37.54 end_price 40.06
# ticker is GO start_index 3783 end_index 3799
# start_price 33.01 end_price 31.15
# ticker is GO start_index 3811 end_index 3827
# start_price 31.0 end_price 32.5
# ticker is GO start_index 3861 end_index 3877
# start_price 35.43 end_price 32.11
# ticker is GO start_index 3902 end_index 3918
# start_price 33.2 end_price 34.79
# ticker is GO start_index 3935 end_index 3951
# start_price 36.67 end_price 36.41
# ticker is GO start_index 3998 end_index 4014
# start_price 44.33 end_price 42.23
# ticker is GO start_index 4062 end_index 4078
# start_price 41.21 end_price 37.62
# ticker is GO start_index 4137 end_index 4153
# start_price 35.91 end_price 36.7
# appending GO
# ticker is HTSI start_index 4212 end_index 4228
# start_price 41.53 end_price 39.26
# ticker is HTSI start_index 4283 end_index 4299
# start_price 36.17 end_price 37.32
# ticker is HTSI start_index 4335 end_index 4351
# start_price 36.95 end_price 43.72
# ticker is HTSI start_index 4397 end_index 4413
# start_price 45.29 end_price 47.69
# ticker is HTSI start_index 4461 end_index 4477
# start_price 49.2 end_price 49.19
# ticker is HTSI start_index 4541 end_index 4557
# start_price 49.38 end_price 49.37
# appending HTSI
# ticker is IFMK start_index 4674 end_index 4690
# start_price 11.99 end_price 13.537
# ticker is IFMK start_index 4705 end_index 4721
# start_price 12.81 end_price 12.92
# ticker is IFMK start_index 4770 end_index 4786
# start_price 11.13 end_price 11.06
# ticker is IFMK start_index 4832 end_index 4848
# start_price 11.92 end_price 8.29
# ticker is IFMK start_index 4926 end_index 4942
# start_price 5.5 end_price 3.929
# ticker is IFMK start_index 4957 end_index 4973
# start_price 3.8 end_price 3.24
# ticker is IFMK start_index 5022 end_index 5038
# start_price 1.4 end_price 1.0
# ticker is IFMK start_index 5083 end_index 5099
# start_price 1.07 end_price 1.47
# ticker is IFMK start_index 5176 end_index 5192
# start_price 1.2 end_price 2.0
# ticker is IFMK start_index 5208 end_index 5224
# start_price 2.27 end_price 2.02
# ticker is IFMK start_index 5273 end_index 5289
# start_price 0.375 end_price 0.368
# ticker is IFMK start_index 5335 end_index 5351
# start_price 0.42200000000000004 end_price 0.753
# ticker is IFMK start_index 5460 end_index 5476
# start_price 0.9390000000000001 end_price 0.91
# ticker is IFMK start_index 5465 end_index 5481
# start_price 0.9 end_price 0.855
# ticker is IFMK start_index 5531 end_index 5547
# start_price 0.8590000000000001 end_price 0.77
# ticker is IFMK start_index 5551 end_index 5567
# start_price 0.8220000000000001 end_price 0.95
# ticker is IFMK start_index 5591 end_index 5607
# start_price 1.95 end_price 1.77
# appending IFMK
# ticker is IMKTA start_index 5666 end_index 5682
# start_price 16.36 end_price 16.19
# ticker is IMKTA start_index 5766 end_index 5782
# start_price 17.2 end_price 17.03
# ticker is IMKTA start_index 5795 end_index 5811
# start_price 19.3 end_price 20.57
# ticker is IMKTA start_index 5857 end_index 5873
# start_price 21.46 end_price 23.31
# ticker is IMKTA start_index 5919 end_index 5935
# start_price 25.69 end_price 24.63
# ticker is IMKTA start_index 6009 end_index 6025
# start_price 24.41 end_price 26.81
# ticker is IMKTA start_index 6044 end_index 6060
# start_price 24.02 end_price 23.43
# ticker is IMKTA start_index 6107 end_index 6123
# start_price 26.07 end_price 27.65
# ticker is IMKTA start_index 6172 end_index 6188
# start_price 24.47 end_price 24.73
# ticker is IMKTA start_index 6263 end_index 6279
# start_price 32.08 end_price 42.12
# ticker is IMKTA start_index 6297 end_index 6313
# start_price 44.06 end_price 43.24
# ticker is IMKTA start_index 6359 end_index 6375
# start_price 40.87 end_price 49.89
# ticker is IMKTA start_index 6421 end_index 6437
# start_price 49.9 end_price 49.35
# ticker is IMKTA start_index 6511 end_index 6527
# start_price 53.84 end_price 38.35
# ticker is IMKTA start_index 6548 end_index 6564
# start_price 36.2 end_price 36.09
# ticker is IMKTA start_index 6611 end_index 6627
# start_price 36.73 end_price 37.44
# ticker is IMKTA start_index 6673 end_index 6689
# start_price 36.86 end_price 38.89
# ticker is IMKTA start_index 6768 end_index 6784
# start_price 48.05 end_price 49.35
# ticker is IMKTA start_index 6798 end_index 6814
# start_price 45.25 end_price 47.65
# ticker is IMKTA start_index 6861 end_index 6877
# start_price 45.85 end_price 37.95
# ticker is IMKTA start_index 6924 end_index 6940
# start_price 29.5 end_price 24.0
# ticker is IMKTA start_index 7012 end_index 7028
# start_price 27.7 end_price 35.4
# ticker is IMKTA start_index 7055 end_index 7071
# start_price 30.55 end_price 33.1
# ticker is IMKTA start_index 7117 end_index 7133
# start_price 30.95 end_price 28.7
# ticker is IMKTA start_index 7181 end_index 7197
# start_price 29.55 end_price 35.95
# ticker is IMKTA start_index 7264 end_index 7280
# start_price 28.1 end_price 27.22
# ticker is IMKTA start_index 7305 end_index 7321
# start_price 28.96 end_price 31.37
# ticker is IMKTA start_index 7367 end_index 7383
# start_price 27.45 end_price 30.92
# ticker is IMKTA start_index 7431 end_index 7447
# start_price 31.75 end_price 38.65
# ticker is IMKTA start_index 7517 end_index 7533
# start_price 43.48 end_price 46.47
# ticker is IMKTA start_index 7556 end_index 7572
# start_price 42.76 end_price 35.77
# ticker is IMKTA start_index 7619 end_index 7635
# start_price 37.61 end_price 42.61
# ticker is IMKTA start_index 7682 end_index 7698
# start_price 39.9 end_price 41.43
# ticker is IMKTA start_index 7768 end_index 7784
# start_price 37.41 end_price 42.26
# ticker is IMKTA start_index 7807 end_index 7823
# start_price 47.26 end_price 51.96
# ticker is IMKTA start_index 7869 end_index 7872
# start_price 62.74 end_price 65.71
# appending IMKTA
# ticker is KR start_index 7926 end_index 7942
# start_price 11.905 end_price 11.77
# ticker is KR start_index 7983 end_index 7999
# start_price 13.325 end_price 13.195
# ticker is KR start_index 8058 end_index 8074
# start_price 16.27 end_price 17.335
# ticker is KR start_index 8120 end_index 8136
# start_price 17.355 end_price 19.525
# ticker is KR start_index 8180 end_index 8196
# start_price 20.24 end_price 20.505
# ticker is KR start_index 8237 end_index 8253
# start_price 19.995 end_price 19.5
# ticker is KR start_index 8310 end_index 8326
# start_price 21.825 end_price 22.725
# ticker is KR start_index 8373 end_index 8389
# start_price 24.715 end_price 25.085
# ticker is KR start_index 8431 end_index 8447
# start_price 26.015 end_price 26.7
# ticker is KR start_index 8490 end_index 8506
# start_price 30.765 end_price 33.1
# ticker is KR start_index 8561 end_index 8577
# start_price 38.62 end_price 35.195
# ticker is KR start_index 8624 end_index 8640
# start_price 36.335 end_price 39.01
# ticker is KR start_index 8682 end_index 8698
# start_price 36.66 end_price 37.44
# ticker is KR start_index 8743 end_index 8759
# start_price 42.43 end_price 41.28
# ticker is KR start_index 8811 end_index 8827
# start_price 38.06 end_price 36.23
# ticker is KR start_index 8875 end_index 8891
# start_price 36.62 end_price 36.4
# ticker is KR start_index 8933 end_index 8949
# start_price 30.79 end_price 30.11
# ticker is KR start_index 8992 end_index 9008
# start_price 34.22 end_price 33.21
# ticker is KR start_index 9063 end_index 9079
# start_price 28.93 end_price 29.95
# ticker is KR start_index 9126 end_index 9142
# start_price 22.61 end_price 22.94
# ticker is KR start_index 9182 end_index 9198
# start_price 21.26 end_price 20.63
# ticker is KR start_index 9241 end_index 9257
# start_price 26.53 end_price 28.3
# ticker is KR start_index 9318 end_index 9334
# start_price 23.28 end_price 25.38
# ticker is KR start_index 9380 end_index 9396
# start_price 28.43 end_price 28.29
# ticker is KR start_index 9440 end_index 9456
# start_price 29.61 end_price 27.2
# ticker is KR start_index 9498 end_index 9514
# start_price 28.92 end_price 28.48
# ticker is KR start_index 9569 end_index 9585
# start_price 24.48 end_price 25.57
# ticker is KR start_index 9630 end_index 9646
# start_price 21.39 end_price 20.86
# ticker is KR start_index 9690 end_index 9706
# start_price 25.72 end_price 24.31
# ticker is KR start_index 9749 end_index 9765
# start_price 28.31 end_price 28.44
# ticker is KR start_index 9821 end_index 9837
# start_price 30.12 end_price 32.88
# ticker is KR start_index 9881 end_index 9897
# start_price 32.78 end_price 34.15
# ticker is KR start_index 9941 end_index 9957
# start_price 33.46 end_price 34.8
# ticker is KR start_index 10000 end_index 10016
# start_price 31.3 end_price 31.82
# ticker is KR start_index 10071 end_index 10087
# start_price 37.95 end_price 37.91
# appending KR
# ticker is NGVC start_index 10196 end_index 10212
# start_price 19.38 end_price 17.99
# ticker is NGVC start_index 10198 end_index 10214
# start_price 19.59 end_price 17.77
# ticker is NGVC start_index 10228 end_index 10244
# start_price 20.32 end_price 21.56
# ticker is NGVC start_index 10296 end_index 10312
# start_price 25.03 end_price 28.35
# ticker is NGVC start_index 10358 end_index 10374
# start_price 35.4 end_price 36.39
# ticker is NGVC start_index 10447 end_index 10463
# start_price 37.94 end_price 42.04
# ticker is NGVC start_index 10479 end_index 10495
# start_price 33.51 end_price 39.83
# ticker is NGVC start_index 10542 end_index 10558
# start_price 35.6 end_price 21.09
# ticker is NGVC start_index 10605 end_index 10621
# start_price 23.88 end_price 18.29
# ticker is NGVC start_index 10698 end_index 10714
# start_price 25.45 end_price 26.77
# ticker is NGVC start_index 10730 end_index 10746
# start_price 28.06 end_price 30.09
# ticker is NGVC start_index 10798 end_index 10814
# start_price 26.87 end_price 24.21
# ticker is NGVC start_index 10856 end_index 10872
# start_price 22.29 end_price 23.85
# ticker is NGVC start_index 10949 end_index 10965
# start_price 20.11 end_price 20.2
# ticker is NGVC start_index 10981 end_index 10997
# start_price 20.67 end_price 19.26
# ticker is NGVC start_index 11049 end_index 11065
# start_price 13.09 end_price 13.63
# ticker is NGVC start_index 11107 end_index 11123
# start_price 13.49 end_price 11.72
# ticker is NGVC start_index 11200 end_index 11216
# start_price 11.69 end_price 11.89
# ticker is NGVC start_index 11237 end_index 11253
# start_price 12.54 end_price 12.46
# ticker is NGVC start_index 11300 end_index 11316
# start_price 10.7 end_price 9.76
# ticker is NGVC start_index 11363 end_index 11379
# start_price 8.61 end_price 5.94
# ticker is NGVC start_index 11451 end_index 11467
# start_price 8.3 end_price 8.93
# ticker is NGVC start_index 11488 end_index 11504
# start_price 8.6 end_price 6.96
# ticker is NGVC C:\Users\Robso\anaconda3\envs\ml\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# start_index 11551 end_index 11567
# start_price 7.19 end_price 10.56
# ticker is NGVC start_index 11614 end_index 11630
# start_price 12.54 end_price 19.26
# ticker is NGVC start_index 11701 end_index 11717
# start_price 17.5 end_price 15.72
# ticker is NGVC start_index 11743 end_index 11759
# start_price 14.0 end_price 14.26
# ticker is NGVC start_index 11801 end_index 11817
# start_price 12.16 end_price 10.74
# ticker is NGVC start_index 11864 end_index 11880
# start_price 9.17 end_price 9.79
# ticker is NGVC start_index 11952 end_index 11968
# start_price 9.32 end_price 10.07
# ticker is NGVC start_index 11994 end_index 12010
# start_price 9.35 end_price 6.9
# ticker is NGVC start_index 12057 end_index 12073
# start_price 10.72 end_price 14.4
# ticker is NGVC start_index 12120 end_index 12136
# start_price 16.06 end_price 13.37
# ticker is NGVC start_index 12208 end_index 12224
# start_price 13.8 end_price 14.07
# ticker is NGVC start_index 12245 end_index 12261
# start_price 16.18 end_price 14.08
# ticker is NGVC start_index 12308 end_index 12310
# start_price 16.08 end_price 12.95
# appending NGVC
# ticker is QKLS start_index 12340 end_index 12356
# start_price 8.08 end_price 6.56
# ticker is QKLS start_index 12403 end_index 12419
# start_price 5.12 end_price 6.8
# ticker is QKLS start_index 12505 end_index 12521
# start_price 5.98 end_price 3.36
# ticker is QKLS start_index 12526 end_index 12542
# start_price 3.43 end_price 4.15
# ticker is QKLS start_index 12590 end_index 12606
# start_price 6.2 end_price 4.48
# ticker is QKLS start_index 12655 end_index 12671
# start_price 4.55 end_price 4.3
# ticker is QKLS start_index 12751 end_index 12767
# start_price 4.33 end_price 3.96
# ticker is QKLS start_index 12779 end_index 12795
# start_price 3.71 end_price 3.52
# ticker is QKLS start_index 12842 end_index 12858
# start_price 3.37 end_price 3.19
# ticker is QKLS start_index 12907 end_index 12923
# start_price 2.31 end_price 1.73
# ticker is QKLS start_index 13009 end_index 13025
# start_price 3.15 end_price 2.33
# ticker is QKLS start_index 13031 end_index 13047
# start_price 3.1 end_price 2.32
# ticker is QKLS start_index 13095 end_index 13111
# start_price 1.64 end_price 1.26
# ticker is QKLS start_index 13159 end_index 13175
# start_price 0.9 end_price 0.84
# ticker is QKLS start_index 13261 end_index 13277
# start_price 0.66 end_price 0.43
# appending QKLS
# ticker is RNDY start_index 14565 end_index 14581
# start_price 7.71 end_price 7.42
# ticker is RNDY start_index 14628 end_index 14644
# start_price 4.24 end_price 4.81
# ticker is RNDY start_index 14716 end_index 14732
# start_price 6.74 end_price 6.52
# ticker is RNDY start_index 14750 end_index 14766
# start_price 7.33 end_price 7.58
# ticker is RNDY start_index 14813 end_index 14829
# start_price 8.57 end_price 8.44
# ticker is RNDY start_index 14877 end_index 14893
# start_price 9.15 end_price 8.49
# ticker is RNDY start_index 14957 end_index 14973
# start_price 6.08 end_price 6.74
# ticker is RNDY start_index 14999 end_index 15015
# start_price 6.65 end_price 5.27
# ticker is RNDY start_index 15062 end_index 15078
# start_price 4.78 end_price 3.74
# ticker is RNDY start_index 15126 end_index 15142
# start_price 3.45 end_price 4.12
# ticker is RNDY start_index 15213 end_index 15229
# start_price 4.48 end_price 5.73
# ticker is RNDY start_index 15255 end_index 15271
# start_price 4.65 end_price 3.28
# ticker is RNDY start_index 15318 end_index 15334
# start_price 2.46 end_price 2.56
# ticker is RNDY start_index 15383 end_index 15399
# start_price 3.57 end_price 3.6
# appending RNDY
# ticker is SFM start_index 15424 end_index 15440
# start_price 38.59 end_price 39.43
# ticker is SFM start_index 15477 end_index 15493
# start_price 48.04 end_price 37.84
# ticker is SFM start_index 15484 end_index 15500
# start_price 43.05 end_price 36.6
# ticker is SFM start_index 15552 end_index 15568
# start_price 36.85 end_price 37.13
# ticker is SFM start_index 15564 end_index 15580
# start_price 37.95 end_price 35.42
# ticker is SFM start_index 15600 end_index 15616
# start_price 31.09 end_price 27.04
# ticker is SFM start_index 15664 end_index 15680
# start_price 31.75 end_price 31.005
# ticker is SFM start_index 15728 end_index 15744
# start_price 30.69 end_price 31.79
# ticker is SFM start_index 15803 end_index 15819
# start_price 37.09 end_price 33.96
# ticker is SFM start_index 15852 end_index 15868
# start_price 31.06 end_price 29.99
# ticker is SFM start_index 15915 end_index 15931
# start_price 24.03 end_price 20.6
# ticker is SFM start_index 15979 end_index 15995
# start_price 19.88 end_price 24.63
# ticker is SFM start_index 16054 end_index 16070
# start_price 25.21 end_price 28.85
# ticker is SFM start_index 16103 end_index 16119
# start_price 27.38 end_price 25.16
# ticker is SFM start_index 16166 end_index 16182
# start_price 23.25 end_price 23.22
# ticker is SFM start_index 16230 end_index 16246
# start_price 22.57 end_price 21.52
# ticker is SFM start_index 16305 end_index 16321
# start_price 19.0 end_price 20.88
# ticker is SFM start_index 16354 end_index 16370
# start_price 22.75 end_price 23.77
# ticker is SFM start_index 16417 end_index 16433
# start_price 23.98 end_price 22.1
# ticker is SFM start_index 16481 end_index 16497
# start_price 18.87 end_price 21.76
# ticker is SFM start_index 16556 end_index 16572
# start_price 26.12 end_price 24.17
# ticker is SFM start_index 16605 end_index 16621
# start_price 24.39 end_price 21.83
# ticker is SFM start_index 16668 end_index 16684
# start_price 21.2 end_price 24.75
# ticker is SFM start_index 16732 end_index 16748
# start_price 26.89 end_price 27.42
# ticker is SFM start_index 16806 end_index 16822
# start_price 24.14 end_price 22.31
# ticker is SFM start_index 16855 end_index 16871
# start_price 21.29 end_price 20.45
# ticker is SFM start_index 16918 end_index 16934
# start_price 16.93 end_price 17.98
# ticker is SFM start_index 16982 end_index 16998
# start_price 18.75 end_price 19.46
# ticker is SFM start_index 17057 end_index 17073
# start_price 15.86 end_price 13.32
# ticker is SFM start_index 17109 end_index 17125
# start_price 21.76 end_price 24.82
# ticker is SFM start_index 17168 end_index 17184
# start_price 27.02 end_price 24.19
# ticker is SFM start_index 17232 end_index 17248
# start_price 20.4 end_price 19.73
# ticker is SFM start_index 17313 end_index 17329
# start_price 21.48 end_price 24.05
# ticker is SFM start_index 17362 end_index 17364
# start_price 25.87 end_price 25.81
# appending SFM
# ticker is SFS start_index 17402 end_index 17418
# start_price 15.49 end_price 15.36
# ticker is SFS start_index 17489 end_index 17505
# start_price 18.4 end_price 18.25
# ticker is SFS start_index 17513 end_index 17529
# start_price 17.87 end_price 17.27
# ticker is SFS start_index 17572 end_index 17588
# start_price 17.79 end_price 16.43
# ticker is SFS start_index 17651 end_index 17667
# start_price 14.6 end_price 17.29
# ticker is SFS start_index 17734 end_index 17750
# start_price 15.8 end_price 15.66
# ticker is SFS start_index 17769 end_index 17785
# start_price 16.03 end_price 15.51
# ticker is SFS start_index 17829 end_index 17845
# start_price 15.03 end_price 13.17
# ticker is SFS start_index 17907 end_index 17923
# start_price 13.45 end_price 13.4
# ticker is SFS start_index 17988 end_index 18004
# start_price 11.55 end_price 11.9
# ticker is SFS start_index 18021 end_index 18037
# start_price 11.65 end_price 13.15
# ticker is SFS start_index 18078 end_index 18094
# start_price 8.1 end_price 7.25
# ticker is SFS start_index 18158 end_index 18174
# start_price 7.25 end_price 8.95
# ticker is SFS start_index 18239 end_index 18255
# start_price 6.0 end_price 5.25
# ticker is SFS start_index 18272 end_index 18288
# start_price 5.3 end_price 4.75
# ticker is SFS start_index 18330 end_index 18346
# start_price 5.5 end_price 6.95
# ticker is SFS start_index 18409 end_index 18425
# start_price 4.95 end_price 5.8
# ticker is SFS start_index 18489 end_index 18505
# start_price 5.26 end_price 5.34
# ticker is SFS start_index 18523 end_index 18539
# start_price 6.52 end_price 6.55
# appending SFS
# ticker is SWY start_index 18571 end_index 18587
# start_price 15.26 end_price 16.13
# ticker is SWY start_index 18630 end_index 18646
# start_price 15.67 end_price 16.41
# ticker is SWY start_index 18718 end_index 18734
# start_price 22.76 end_price 24.89
# ticker is SWY start_index 18762 end_index 18778
# start_price 23.51 end_price 24.31
# ticker is SWY start_index 18821 end_index 18837
# start_price 25.57 end_price 25.74
# ticker is SWY start_index 18880 end_index 18896
# start_price 32.74 end_price 34.25
# ticker is SWY start_index 18970 end_index 18986
# start_price 37.13 end_price 38.38
# ticker is SWY start_index 19014 end_index 19030
# start_price 34.08 end_price 34.37
# ticker is SWY start_index 19071 end_index 19087
# start_price 34.82 end_price 34.42
# ticker is SWY start_index 19131 end_index 19147
# start_price 33.97 end_price 34.97
# appending SWY
# ticker is TFM start_index 19250 end_index 19266
# start_price 58.34 end_price 59.01
# ticker is TFM start_index 19312 end_index 19328
# start_price 50.7 end_price 47.65
# ticker is TFM start_index 19387 end_index 19403
# start_price 42.7 end_price 39.26
# ticker is TFM start_index 19436 end_index 19452
# start_price 50.26 end_price 50.84
# ticker is TFM start_index 19500 end_index 19516
# start_price 49.7 end_price 47.59
# ticker is TFM start_index 19557 end_index 19573
# start_price 39.97 end_price 40.39
# ticker is TFM start_index 19635 end_index 19651
# start_price 34.18 end_price 34.8
# ticker is TFM start_index 19686 end_index 19702
# start_price 32.95 end_price 34.15
# ticker is TFM start_index 19750 end_index 19766
# start_price 33.73 end_price 34.33
# ticker is TFM start_index 19814 end_index 19830
# start_price 39.53 end_price 41.42
# ticker is TFM start_index 19887 end_index 19903
# start_price 41.09 end_price 40.09
# ticker is TFM start_index 19933 end_index 19949
# start_price 32.43 end_price 31.89
# ticker is TFM start_index 19997 end_index 20013
# start_price 19.91 end_price 23.74
# ticker is TFM start_index 20063 end_index 20079
# start_price 23.98 end_price 24.24
# ticker is TFM start_index 20140 end_index 20156
# start_price 28.47 end_price 28.595
# appending TFM
# ticker is VLGEA start_index 20234 end_index 20250
# start_price 34.06 end_price 36.86
# ticker is VLGEA start_index 20272 end_index 20288
# start_price 37.11 end_price 31.8
# ticker is VLGEA start_index 20333 end_index 20349
# start_price 34.1 end_price 33.85
# ticker is VLGEA start_index 20396 end_index 20412
# start_price 36.37 end_price 33.05
# ticker is VLGEA start_index 20483 end_index 20499
# start_price 34.85 end_price 37.84
# ticker is VLGEA start_index 20523 end_index 20539
# start_price 38.45 end_price 31.78
# ticker is VLGEA start_index 20583 end_index 20599
# start_price 27.32 end_price 26.74
# ticker is VLGEA start_index 20647 end_index 20663
# start_price 22.89 end_price 23.72
# ticker is VLGEA start_index 20735 end_index 20751
# start_price 23.46 end_price 25.95
# ticker is VLGEA start_index 20774 end_index 20790
# start_price 24.04 end_price 26.25
# ticker is VLGEA start_index 20835 end_index 20851
# start_price 27.66 end_price 30.98
# ticker is VLGEA start_index 20898 end_index 20914
# start_price 32.29 end_price 31.53
# ticker is VLGEA start_index 20986 end_index 21002
# start_price 25.39 end_price 25.8
# ticker is VLGEA start_index 21026 end_index 21042
# start_price 25.61 end_price 27.0
# ticker is VLGEA start_index 21086 end_index 21102
# start_price 26.41 end_price 23.54
# ticker is VLGEA start_index 21150 end_index 21166
# start_price 27.37 end_price 29.28
# ticker is VLGEA start_index 21242 end_index 21258
# start_price 31.72 end_price 30.84
# ticker is VLGEA start_index 21281 end_index 21297
# start_price 35.63 end_price 31.63
# ticker is VLGEA start_index 21343 end_index 21359
# start_price 27.06 end_price 26.45
# ticker is VLGEA start_index 21405 end_index 21421
# start_price 25.07 end_price 26.12
# ticker is VLGEA start_index 21494 end_index 21510
# start_price 24.9 end_price 24.22
# ticker is VLGEA start_index 21531 end_index 21547
# start_price 25.44 end_price 23.15
# ticker is VLGEA start_index 21594 end_index 21610
# start_price 24.07 end_price 26.37
# ticker is VLGEA start_index 21657 end_index 21673
# start_price 28.29 end_price 29.51
# ticker is VLGEA start_index 21745 end_index 21761
# start_price 24.9 end_price 25.15
# ticker is VLGEA start_index 21783 end_index 21799
# start_price 25.44 end_price 26.58
# ticker is VLGEA start_index 21843 end_index 21859
# start_price 31.5 end_price 27.88
# ticker is VLGEA start_index 21905 end_index 21921
# start_price 26.18 end_price 26.83
# ticker is VLGEA start_index 21995 end_index 22011
# start_price 26.27 end_price 26.5
# ticker is VLGEA start_index 22034 end_index 22050
# start_price 25.79 end_price 23.7
# ticker is VLGEA start_index 22095 end_index 22111
# start_price 21.35 end_price 23.0
# ticker is VLGEA start_index 22158 end_index 22174
# start_price 25.46 end_price 26.02
# ticker is VLGEA start_index 22246 end_index 22262
# start_price 24.32 end_price 23.06
# ticker is VLGEA start_index 22285 end_index 22301
# start_price 23.13 end_price 21.79
# ticker is VLGEA start_index 22346 end_index 22362
# start_price 23.88 end_price 24.64
# appending VLGEA
# ticker is WFM start_index 22415 end_index 22431
# start_price 46.455 end_price 48.515
# ticker is WFM start_index 22490 end_index 22506
# start_price 46.711999999999996 end_price 44.61
# ticker is WFM start_index 22552 end_index 22568
# start_price 42.465 end_price 43.53
# ticker is WFM start_index 22611 end_index 22627
# start_price 51.02 end_price 52.05
# ticker is WFM start_index 22669 end_index 22685
# start_price 55.9 end_price 52.75
# ticker is WFM start_index 22743 end_index 22759
# start_price 56.48 end_price 56.09
# ticker is WFM start_index 22803 end_index 22819
# start_price 52.35 end_price 53.93
# ticker is WFM start_index 22862 end_index 22878
# start_price 38.76 end_price 41.14
# ticker is WFM start_index 22920 end_index 22936
# start_price 37.35 end_price 39.14
# ticker is WFM start_index 22994 end_index 23010
# start_price 47.69 end_price 48.54
# ticker is WFM start_index 23059 end_index 23075
# start_price 56.73 end_price 53.97
# ticker is WFM start_index 23113 end_index 23129
# start_price 42.9 end_price 39.995
# ticker is WFM start_index 23171 end_index 23187
# start_price 34.84 end_price 32.85
# ticker is WFM start_index 23240 end_index 23256
# start_price 29.91 end_price 30.69
# ticker is WFM start_index 23310 end_index 23326
# start_price 30.86 end_price 33.42
# ticker is WFM start_index 23364 end_index 23380
# start_price 30.51 end_price 34.91
# ticker is WFM start_index 23422 end_index 23438
# start_price 30.39 end_price 30.73
# ticker is WFM start_index 23496 end_index 23512
# start_price 30.94 end_price 31.04
# ticker is WFM start_index 23556 end_index 23572
# start_price 30.72 end_price 29.19
# ticker is WFM start_index 23620 end_index 23636
# start_price 36.15 end_price 35.32
# ticker is WFM start_index 23673 end_index 23689
# start_price 41.84 end_price 41.99
# appending WFM
# ticker is WMK start_index 23717 end_index 23733
# start_price 43.27 end_price 42.45
# ticker is WMK start_index 23779 end_index 23795
# start_price 40.38 end_price 39.11
# ticker is WMK start_index 23864 end_index 23880
# start_price 41.02 end_price 40.25
# ticker is WMK start_index 23903 end_index 23919
# start_price 42.49 end_price 40.91
# ticker is WMK start_index 23966 end_index 23982
# start_price 50.81 end_price 47.82
# ticker is WMK start_index 24030 end_index 24046
# start_price 49.21 end_price 51.03
# ticker is WMK start_index 24116 end_index 24132
# start_price 49.49 end_price 48.75
# ticker is WMK start_index 24154 end_index 24170
# start_price 45.2 end_price 47.37
# ticker is WMK start_index 24217 end_index 24233
# start_price 43.43 end_price 43.09
# ticker is WMK start_index 24281 end_index 24297
# start_price 44.63 end_price 46.12
# ticker is WMK start_index 24367 end_index 24383
# start_price 50.36 end_price 49.7
# ticker is WMK start_index 24401 end_index 24417
# start_price 44.35 end_price 43.5
# ticker is WMK start_index 24466 end_index 24482
# start_price 42.01 end_price 39.65
# ticker is WMK start_index 24600 end_index 24616
# start_price 38.92 end_price 42.26
# ticker is WMK start_index 24623 end_index 24639
# start_price 43.38 end_price 43.74
# ticker is WMK start_index 24656 end_index 24672
# start_price 45.43 end_price 49.6
# ticker is WMK start_index 24714 end_index 24730
# start_price 51.55 end_price 51.05
# ticker is WMK start_index 24783 end_index 24799
# start_price 56.51 end_price 57.26
# ticker is WMK start_index 24873 end_index 24889
# start_price 59.08 end_price 59.68
# ticker is WMK start_index 24912 end_index 24928
# start_price 57.79 end_price 52.79
# ticker is WMK start_index 24975 end_index 24991
# start_price 44.49 end_price 44.21
# ticker is WMK start_index 25037 end_index 25053
# start_price 34.0 end_price 40.84
# ticker is WMK start_index 25124 end_index 25140
# start_price 38.37 end_price 43.39
# ticker is WMK start_index 25163 end_index 25179
# start_price 48.03 end_price 55.2
# ticker is WMK start_index 25225 end_index 25241
# start_price 48.66 end_price 46.47
# ticker is WMK start_index 25290 end_index 25306
# start_price 46.46 end_price 45.8
# ticker is WMK start_index 25374 end_index 25390
# start_price 40.5 end_price 41.33
# ticker is WMK start_index 25413 end_index 25429
# start_price 38.77 end_price 37.8
# ticker is WMK start_index 25474 end_index 25490
# start_price 37.6 end_price 38.5
# ticker is WMK start_index 25537 end_index 25553
# start_price 38.87 end_price 39.86
# ticker is WMK start_index 25625 end_index 25641
# start_price 36.39 end_price 43.55
# ticker is WMK start_index 25664 end_index 25680
# start_price 54.64 end_price 55.73
# ticker is WMK start_index 25726 end_index 25742
# start_price 51.17 end_price 49.54
# ticker is WMK start_index 25791 end_index 25807
# start_price 46.35 end_price 47.87
# ticker is WMK start_index 25876 end_index 25892
# start_price 58.85 end_price 56.88
# ticker is WMK start_index 25915 end_index 25917
# start_price 52.64 end_price 53.68
# appending WMK

# %%
len(lister)
# Out:
# 20

# %%
combined_df = pd.concat([i for i in lister])
len(combined_df)
combined_df.head()
# Out:
#   ticker       date  cum_ret
# 0    ACI 2020-06-26      NaN
# 1    ACI 2020-06-29      NaN
# 2    ACI 2020-06-30      NaN
# 3    ACI 2020-07-01      NaN
# 4    ACI 2020-07-02      NaN

# %%
df_fin = pd.merge(df_sic_peers, combined_df, on=["ticker", "date"], how="left")

# %%
df_fin.shape
df_fin.head()
# Out:
# 3        0.403  1.194  13.096  13.125  1.090125e+09        0.0  49.35  0.344
# 4        0.313  1.343  18.000  18.047  1.094591e+09        0.0  53.78  0.396
#
#      ps1  receivables       retearn       revenue    revenueusd  rnd  roa  \
# 0  0.353   44598000.0  1.299653e+09  1.006340e+09  1.006340e+09  0.0  NaN
# 1  0.386   56760000.0  1.283737e+09  1.025691e+09  1.025691e+09  0.0  NaN
# 2  0.315   50726000.0  1.272655e+09  1.002387e+09  1.002387e+09  0.0  NaN
# 3  0.344   48541000.0  1.249657e+09  1.098704e+09  1.098704e+09  0.0  NaN
# 4  0.396   56952000.0  1.216524e+09  9.858200e+08  9.858200e+08  0.0  NaN
#
#    roe  roic  ros  sbcomp         sgna  sharefactor   sharesbas    shareswa  \
# 0  NaN   NaN  NaN     0.0  235556000.0          1.0  26898443.0  26898443.0
# 1  NaN   NaN  NaN     0.0  242126000.0          1.0  26898443.0  26898443.0
# 2  NaN   NaN  NaN     0.0  231527000.0          1.0  26898443.0  26898443.0
# 3  NaN   NaN  NaN     0.0  236886000.0          1.0  26898443.0  26898443.0
# 4  NaN   NaN  NaN     0.0  226719000.0          1.0  26898443.0  26898443.0
#
#    shareswadil     sps     tangibles  taxassets      taxexp  taxliabilities  \
# 0   26898443.0  37.413  1.715185e+09        0.0   8415000.0     115435000.0
# 1   26898443.0  38.132  1.750532e+09        0.0   8246000.0     108462000.0
# 2   26898443.0  37.266  1.686571e+09        0.0  12142000.0     109646000.0
# 3   26898443.0  40.846  1.668504e+09        0.0  14978000.0     129294000.0
# 4   26898443.0  36.650  1.646325e+09        0.0   9396000.0     114581000.0
#
#     tbvps  workingcapital   cum_ret
# 0  63.765     288957000.0  0.019757
# 1  65.079     279933000.0 -0.033475
# 2  62.701     286083000.0  0.032794
# 3  62.030     267061000.0 -0.031855
# 4  61.205     229925000.0  0.019949

# %%
df_fin.sort_values(by=["ticker", "date"], ascending=[True, True], inplace=True)

# %%
df_fin[["ticker", "date", "cum_ret"]]
# Out:
#     ticker       date   cum_ret
# 383    ACI 2018-05-11       NaN
# 382    ACI 2018-07-25       NaN
# 381    ACI 2018-10-18       NaN
# 380    ACI 2019-01-15       NaN
# 379    ACI 2019-04-24       NaN
# 378    ACI 2019-07-24       NaN
# 377    ACI 2019-10-16       NaN
# 376    ACI 2020-01-08       NaN
# 375    ACI 2020-05-13       NaN
# 374    ACI 2020-06-18       NaN
# 373    ACI 2020-08-04 -0.016183
# 372    ACI 2020-10-21 -0.015769
# 371    ACI 2021-01-13 -0.022807
# 370    ACI 2021-04-28  0.059083
# 369  ARDNA 2012-08-03  0.077482
# 368  ARDNA 2012-11-06  0.168023
# 367  ARDNA 2013-03-11  0.018716
# 366  ARDNA 2013-05-08  0.090117
# 365  ARDNA 2013-08-08  0.013707
# 364  ARDNA 2013-11-07  0.001078
# 363   ASAI 2021-01-25       NaN
# 362   ASAI 2021-04-29  0.138420
# 361  FWMHQ 2013-04-17       NaN
# 360  FWMHQ 2013-06-06  0.156295
# 359  FWMHQ 2013-08-08 -0.127758
# 358  FWMHQ 2013-11-07 -0.254124
# 357  FWMHQ 2014-02-06 -0.299820
# 356  FWMHQ 2014-05-29  0.005926
# 355  FWMHQ 2014-08-07 -0.214286
# 354  FWMHQ 2014-11-06  0.432432
# 353  FWMHQ 2015-02-05  0.109562
# 352  FWMHQ 2015-05-26 -0.127430
# 351  FWMHQ 2015-08-04 -0.215232
# 350  FWMHQ 2015-10-29 -0.368421
# 349  FWMHQ 2016-02-05 -0.396794
# 348     GO 2019-06-20       NaN
# 347     GO 2019-08-13  0.067128
# 346     GO 2019-10-03 -0.056347
# 345     GO 2019-11-12  0.048387
# 344     GO 2020-01-27 -0.093706
# 343     GO 2020-03-25  0.047892
# 342     GO 2020-05-12 -0.007090
# 341     GO 2020-08-11 -0.047372
# 340     GO 2020-11-10 -0.087115
# 339     GO 2021-03-02  0.021999
# 338   HTSI 2012-08-09 -0.054659
# 337   HTSI 2012-11-21  0.031794
# 336   HTSI 2013-02-07  0.183221
# 335   HTSI 2013-05-08  0.052992
# 334   HTSI 2013-08-08 -0.000203
# 333   HTSI 2013-12-02 -0.000203
# 332   IFMK 2016-08-10       NaN
# 331   IFMK 2016-10-19       NaN
# 330   IFMK 2016-11-10       NaN
# 329   IFMK 2016-12-09       NaN
# 328   IFMK 2016-12-16       NaN
# 327   IFMK 2017-06-29  0.129024
# 326   IFMK 2017-08-14  0.008587
# 325   IFMK 2017-11-14 -0.006289
# 324   IFMK 2018-02-14 -0.304530
# 323   IFMK 2018-06-29 -0.285636
# 322   IFMK 2018-08-14 -0.147368
# 321   IFMK 2018-11-14 -0.285714
# 320   IFMK 2019-02-14  0.373832
# 319   IFMK 2019-06-28  0.666667
# 318   IFMK 2019-08-14 -0.110132
# 317   IFMK 2019-11-14 -0.018667
# 316   IFMK 2020-02-14  0.784360
# 315   IFMK 2020-08-13 -0.030884
# 314   IFMK 2020-08-20 -0.050000
# 313   IFMK 2020-11-23 -0.103609
# 312   IFMK 2020-12-22  0.155718
# 311   IFMK 2021-02-22 -0.092308
# 310  IMKTA 2012-08-01 -0.010391
# 309  IMKTA 2012-12-26 -0.009884
# 308  IMKTA 2013-02-07  0.065803
# 307  IMKTA 2013-05-08  0.086207
# 306  IMKTA 2013-08-06 -0.041261
# 305  IMKTA 2013-12-12  0.098320
# 304  IMKTA 2014-02-04 -0.024563
# 303  IMKTA 2014-05-06  0.060606
# 302  IMKTA 2014-08-07  0.010625
# 301  IMKTA 2014-12-16  0.312968
# 300  IMKTA 2015-02-05 -0.018611
# 299  IMKTA 2015-05-06  0.220700
# 298  IMKTA 2015-08-04 -0.011022
# 297  IMKTA 2015-12-10 -0.287704
# 296  IMKTA 2016-02-04 -0.003039
# 295  IMKTA 2016-05-05  0.019330
# 294  IMKTA 2016-08-03  0.055073
# 293  IMKTA 2016-12-16  0.027055
# 292  IMKTA 2017-02-01  0.053039
# 291  IMKTA 2017-05-03 -0.172301
# 290  IMKTA 2017-08-02 -0.186441
# 289  IMKTA 2017-12-06  0.277978
# 288  IMKTA 2018-02-08  0.083470
# 287  IMKTA 2018-05-09 -0.072698
# 211   NGVC 2019-02-07  0.018571
# 210   NGVC 2019-05-02 -0.116776
# 209   NGVC 2019-08-01  0.067612
# 208   NGVC 2019-12-05  0.080472
# 207   NGVC 2020-02-06 -0.262032
# 206   NGVC 2020-05-07  0.343284
# 205   NGVC 2020-08-06 -0.167497
# 204   NGVC 2020-12-10  0.019565
# 203   NGVC 2021-02-04 -0.129790
# 202   NGVC 2021-05-06 -0.194652
# 201   QKLS 2012-08-14 -0.188119
# 200   QKLS 2012-11-14  0.328125
# 199   QKLS 2013-04-15 -0.438127
# 198   QKLS 2013-05-14  0.209913
# 197   QKLS 2013-08-14 -0.277419
# 196   QKLS 2013-11-14 -0.054945
# 195   QKLS 2014-04-04 -0.085450
# 194   QKLS 2014-05-15 -0.051213
# 193   QKLS 2014-08-14 -0.053412
# 192   QKLS 2014-11-14 -0.251082
# 191   QKLS 2015-04-15 -0.260317
# 190   QKLS 2015-05-15 -0.251613
# 189   QKLS 2015-08-17 -0.231707
# 188   QKLS 2015-11-16 -0.066667
# 187   QKLS 2016-04-14 -0.348485
# 186   RNDY 2012-08-13 -0.037613
# 185   RNDY 2012-11-13  0.134434
# 184   RNDY 2013-03-22 -0.032641
# 183   RNDY 2013-05-10  0.034106
# 182   RNDY 2013-08-09 -0.015169
# 181   RNDY 2013-11-08 -0.072131
# 180   RNDY 2014-03-07  0.108553
# 179   RNDY 2014-05-07 -0.207519
# 178   RNDY 2014-08-06 -0.217573
# 177   RNDY 2014-11-05  0.194203
# 176   RNDY 2015-03-13  0.279018
# 175   RNDY 2015-05-13 -0.294624
# 174   RNDY 2015-08-12  0.040650
# 173   RNDY 2015-11-12  0.008403
# 172    SFM 2013-07-22       NaN
# 171    SFM 2013-07-29       NaN
# 170    SFM 2013-08-23  0.021767
# 169    SFM 2013-11-07 -0.212323
# 168    SFM 2013-11-18 -0.149826
# 167    SFM 2014-02-27  0.007598
# 166    SFM 2014-03-17 -0.066667
# 165    SFM 2014-05-07 -0.130267
# 164    SFM 2014-08-07 -0.023465
# 163    SFM 2014-11-06  0.035842
# 162    SFM 2015-02-26 -0.084389
# 161    SFM 2015-05-07 -0.034449
# 160    SFM 2015-08-06 -0.142738
# 159    SFM 2015-11-05  0.238934
# 158    SFM 2016-02-25  0.144387
# 157    SFM 2016-05-05 -0.081081
# 156    SFM 2016-08-04 -0.001290
# 155    SFM 2016-11-03 -0.046522
# 154    SFM 2017-02-23  0.098947
# 153    SFM 2017-05-04  0.044835
# 152    SFM 2017-08-03 -0.078399
# 151    SFM 2017-11-02  0.153153
# 150    SFM 2018-02-22 -0.074655
# 149    SFM 2018-05-03 -0.104961
# 148    SFM 2018-08-02  0.167453
# 147    SFM 2018-11-01  0.019710
# 146    SFM 2019-02-21 -0.075808
# 145    SFM 2019-05-02 -0.039455
# 144    SFM 2019-08-01  0.062020
# 143    SFM 2019-10-31  0.037867
# 142    SFM 2020-02-20 -0.160151
# 141    SFM 2020-05-05  0.140625
# 140    SFM 2020-07-29 -0.104737
# 139    SFM 2020-10-28 -0.032843
# 64   VLGEA 2019-06-04  0.024828
# 63   VLGEA 2019-10-10  0.008755
# 62   VLGEA 2019-12-05 -0.081039
# 61   VLGEA 2020-03-05  0.077283
# 60   VLGEA 2020-06-04  0.021995
# 59   VLGEA 2020-10-08 -0.051809
# 58   VLGEA 2020-12-03 -0.057933
# 57   VLGEA 2021-03-04  0.031826
# 56     WFM 2012-08-03  0.044344
# 55     WFM 2012-11-21 -0.044999
# 54     WFM 2013-02-22  0.025079
# 53     WFM 2013-05-17  0.020188
# 52     WFM 2013-08-09 -0.056351
# 51     WFM 2013-11-22 -0.006905
# 50     WFM 2014-02-21  0.030181
# 49     WFM 2014-05-16  0.061404
# 48     WFM 2014-08-08  0.047925
# 47     WFM 2014-11-21  0.017823
# 46     WFM 2015-02-27 -0.048652
# 45     WFM 2015-05-15 -0.067716
# 44     WFM 2015-08-07 -0.057118
# 43     WFM 2015-11-13  0.026078
# 42     WFM 2016-02-26  0.082955
# 41     WFM 2016-05-13  0.144215
# 40     WFM 2016-08-05  0.011188
# 39     WFM 2016-11-18  0.003232
# 38     WFM 2017-02-16 -0.049805
# 37     WFM 2017-05-19 -0.022960
# 36     WFM 2017-08-04  0.003585
# 35     WMK 2012-08-09 -0.018951
# 34     WMK 2012-11-08 -0.031451
# 33     WMK 2013-03-14 -0.018771
# 32     WMK 2013-05-09 -0.037185
# 31     WMK 2013-08-08 -0.058847
# 30     WMK 2013-11-07  0.036984
# 29     WMK 2014-03-14 -0.014953
# 28     WMK 2014-05-08  0.048009
# 27     WMK 2014-08-07 -0.007829
# 26     WMK 2014-11-06  0.033386
# 25     WMK 2015-03-13 -0.013106
# 24     WMK 2015-05-01 -0.019166
# 23     WMK 2015-08-04 -0.056177
# 22     WMK 2016-02-16  0.085817
# 21     WMK 2016-03-18  0.008299
# 20     WMK 2016-05-05  0.091790
# 19     WMK 2016-07-28 -0.009699
# 18     WMK 2016-11-03  0.013272
# 17     WMK 2017-03-16  0.010156
# 16     WMK 2017-05-11 -0.086520
# 15     WMK 2017-08-10 -0.006294
# 14     WMK 2017-11-07  0.201176
# 13     WMK 2018-03-15  0.130831
# 12     WMK 2018-05-10  0.149282
# 11     WMK 2018-08-08 -0.045006
# 10     WMK 2018-11-08 -0.014206
# 9      WMK 2019-03-14  0.020494
# 8      WMK 2019-05-09 -0.025019
# 7      WMK 2019-08-06  0.023936
# 6      WMK 2019-11-04  0.025470
# 5      WMK 2020-03-12  0.196757
# 4      WMK 2020-05-07  0.019949
# 3      WMK 2020-08-05 -0.031855
# 2      WMK 2020-11-05  0.032794
# 1      WMK 2021-03-11 -0.033475
# 0      WMK 2021-05-06  0.019757

# %%
len(df_fin["ticker"].unique())
# Out:
# 19

# %%
df_fin["ticker"].unique()
# Out:
# array(['ACI', 'ARDNA', 'ASAI', 'FWMHQ', 'GO', 'HTSI', 'IFMK', 'IMKTA',
#        'KR', 'NGVC', 'QKLS', 'RNDY', 'SFM', 'SFS', 'SWY', 'TFM', 'VLGEA',
#        'WFM', 'WMK'], dtype=object)
